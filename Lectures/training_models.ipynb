# %% [markdown]
# ## Scaling features is important for gd:
# <br />
# <img src="../data/gd_scaling.png" />
# <br />
#
#
# ## Gradient descent with adaptive learning rate
# <br />
# <img src="../data/gd_simple.png" />
# <br />
#
# ## Setting the LR too high has adverse consequences:
# <br />
# <img src="../data/lr_too_high.png" />
# <br />
#
# ## Same if it's too small:
# <br />
# <img src="../data/lr_too_small.png" />
# <br />
#
# ## Regularization is a tradeoff between variance and bias:
# <br />
# <img src="../data/regularization_tradeoff.png" height="600" width="800" />
#
# ## While MSE and Logistic regression has _convex_ cost functions, that's not true in general:
# <br />
# <img src="../data/gd_non_smooth.png" />
# <br />
